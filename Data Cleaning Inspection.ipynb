# %%
import pandas as pd

# %%
inspection_data = pd.read_csv('Restaurant_Inspections_Open_Data.csv')

# %%
inspection_data.head(2)
# Out:
#   Serial_Number Permit_Number                   Restaurant_Name  \
# 0     DADUHPSV0     PR0008615           BELLAGIO CHOC PUMP ROOM
# 1     DAWNDIZHU     PR0022465  Yard House - Prep 1 Pantry #8327
#
#                 Location_Name         Category_Name                  Address  \
# 0  BELLAGIO RESORT AND CASINO       Special Kitchen    3600 S Las Vegas Blvd
# 1   Yard House Summerlin, LLC  Meat/Poultry/Seafood  11011 W Charleston Blvd
#
#         City   State         Zip  Current_Demerits  ... Employee_ID  \
# 0  Las Vegas  Nevada  89109-4303                 0  ...   EE7001186
# 1  Las Vegas  Nevada  89135-1402                 3  ...   EE7001291
#
#       Inspection_Type Inspection_Demerits Inspection_Grade Permit_Status  \
# 0  Routine Inspection                   0                A           NaN
# 1  Routine Inspection                   3                A           NaN
#
#   Inspection_Result  Violations            Record_Updated  \
# ...

# %%
inspection_data.columns
# Out:
# Index(['Serial_Number', 'Permit_Number', 'Restaurant_Name', 'Location_Name',
#        'Category_Name', 'Address', 'City', 'State', 'Zip', 'Current_Demerits',
#        'Current_Grade', 'Date_Current', 'Inspection_Date', 'Inspection_Time',
#        'Employee_ID', 'Inspection_Type', 'Inspection_Demerits',
#        'Inspection_Grade', 'Permit_Status', 'Inspection_Result', 'Violations',
#        'Record_Updated', 'Location_1', 'ObjectId'],
#       dtype='object')

# %%
inspection_data_keep = inspection_data.drop(columns=['Permit_Number', 'State', 'Zip', 'Inspection_Time', 'Employee_ID', 'Permit_Status', 'Record_Updated'])

# %%
inspection_data_keep['Latitude'] = 0.0
inspection_data_keep['Longitude'] = 0.0
inspection_data_keep.dtypes
# Out:
# Serial_Number           object
# Restaurant_Name         object
# Location_Name           object
# Category_Name           object
# Address                 object
# City                    object
# Current_Demerits         int64
# Current_Grade           object
# Date_Current            object
# Inspection_Date         object
# Inspection_Type         object
# Inspection_Demerits      int64
# Inspection_Grade        object
# Inspection_Result       object
# Violations             float64
# Location_1              object
# ObjectId                 int64
# Latitude               float64
# Longitude              float64
# dtype: object

# %%
lat_list = []
long_list = []
for row in inspection_data_keep.iterrows():
    location = row[1]['Location_1']
    lat_long = location.split(',')
    rownum = row[0]
    print(type(rownum))
    lat_list.append(round(float(lat_long[0].split('(')[1]),5))
    long_list.append(round(float(lat_long[1].split(')')[0]),5))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
inspection_data_keep['latitude'] = lat_list
inspection_data_keep['longitude'] = long_list

# %%
inspection_data_keep.head(3)
# Out:
#   Serial_Number                   Restaurant_Name               Location_Name  \
# 0     DADUHPSV0           BELLAGIO CHOC PUMP ROOM  BELLAGIO RESORT AND CASINO
# 1     DAWNDIZHU  Yard House - Prep 1 Pantry #8327   Yard House Summerlin, LLC
# 2     DAXPEDNFX             TEA & WHISK SNACK BAR                 TEA & WHISK
#
#           Category_Name                  Address       City  Current_Demerits  \
# 0       Special Kitchen    3600 S Las Vegas Blvd  Las Vegas                 0
# 1  Meat/Poultry/Seafood  11011 W Charleston Blvd  Las Vegas                 3
# 2             Snack Bar  10271 S EASTERN Ave 116  Henderson                 0
#
#   Current_Grade              Date_Current           Inspection_Date  ...  \
# 0             A  2020-01-24T00:00:00.000Z  2020-01-24T00:00:00.000Z  ...
# 1             A  2020-01-24T00:00:00.000Z  2020-01-24T00:00:00.000Z  ...
# 2             A  2020-01-24T00:00:00.000Z  2020-01-24T00:00:00.000Z  ...
#
# ...

# %%
inspection_data_keep.columns
# Out:
# Index(['Serial_Number', 'Restaurant_Name', 'Location_Name', 'Category_Name',
#        'Address', 'City', 'Current_Demerits', 'Current_Grade', 'Date_Current',
#        'Inspection_Date', 'Inspection_Type', 'Inspection_Demerits',
#        'Inspection_Grade', 'Inspection_Result', 'Violations', 'Location_1',
#        'ObjectId', 'Latitude', 'Longitude', 'latitude', 'longitude'],
#       dtype='object')

# %%
inspection_data_keep.to_csv('inspection_cleaned.csv')
